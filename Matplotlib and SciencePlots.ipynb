# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install SciencePlots
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scienceplots

# %% [markdown]
# ## Basic 1D Plots

# %% [markdown]
# ### Line Plots

# %%
x_values = np.linspace(0,10,5)

# %%
x_values
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
y_values = x_values**2

# %%
y_values
# Out:
# array([  0.  ,   6.25,  25.  ,  56.25, 100.  ])

# %%
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# #### Let's increase the number of points

# %%
x_values = np.linspace(0,10,100)
x_values
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y_values = x_values**2

# %%
plt.plot(x_values, y_values)
plt.show() # Smooth Curve

# %%
plt.plot(x_values, y_values, color = "red", ls = "--")
plt.show()

# %%
x = np.linspace(-2,2,10)
y = x**2
plt.plot(x,y,"o--", color = "red", lw = 2, ms = 10)

# %%
plt.figure(figsize = (10,4))
plt.plot(x,y)

# %%
# When we have more than one plot, we need to label things

# %%
x = np.linspace(-2,2,100)
y = 4*np.sin(x)
y1 = 4*np.cos(x)

# %%
plt.figure(figsize = (10,4))
plt.plot(x, y1, ls = "--", label = r"$\sin(x)$")
plt.plot(x,y, label = r"$\cos(x)$")
plt.xlabel("x-axis", fontsize = 16)
plt.ylabel("y-axis")
plt.title("Plots of different Functions")
plt.legend(loc = 'lower right', fontsize=12, ncol=1)
plt.show()

# %%
y2 = np.cos(x**2)
y3 = np.sin(x*6)
plt.figure(figsize = (10,4))
plt.plot(x, y1, ls = "dotted", label = r"$\sin(x)$")
plt.plot(x, y, label = r"$\cos(x)$", ls = "dashed")
plt.plot(x, y2, label = r"$\cos(x^2)$", ls = ":" )
plt.plot(x, y3, label = r"$\cos(6x)$")
plt.xlabel("x-axis", fontsize = 16)
plt.ylabel("y-axis")
plt.title("Plots of Different Functions")
plt.legend(loc='lower right', fontsize=12, ncol=2) #ncol tells the how many columns will be there
plt.show()

# %%
plt.savefig("plot.pdf")

# %%
x_1 = np.linspace(-5,5,num=100)
y_1 = x_1**3
y_2 = x_1**2

# %%
fig = plt.figure(figsize = (10,10))
plt.tight_layout()
plt.plot(x_1,y_1, "r-", label ="$y = x^3$")   # first plot
plt.plot(x_1,y_2, "b-.", label = "$y = x^2$") # second plot
plt.xlim(-5,5)                                # x-axis limits
plt.ylim(-30,30)                              # y-axis limits
plt.xlabel("x")                               # x-axis label
plt.ylabel("y = f(x)")                        # y-axis label 
plt.title("A simple plot")                    #plot title
plt.grid(visible = True)                      # Grid visibility
plt.legend()                                  # legends
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %% [markdown]
# ## Scatter Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt 

x = np.linspace(0, 15, 30)
y = np.sin(x) + 0.1 * np.random.randn(len(x))
x1 = np.linspace(0, 15, 100)
y1 = np.sin(x1)

plt.figure(figsize=(8, 3))
plt.scatter(x, y, label='Data')
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]', fontsize = 16)
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='upper left', fontsize=12, ncol=2)
plt.ylim(top=2)
plt.show()

# %%
x_2 = np.linspace(-mt.pi, mt.pi)
y_3 = np.sin(x_2)

# %%
fig = plt.figure(figsize=(10,10))
fig.tight_layout()

plt.scatter(x_2, y_3, label ="y = cos(x)")

plt.xlim(-mt.pi, mt.pi)
plt.ylim(-1,1)
plt.xlabel("x")
plt.ylabel("y = g(x)")
plt.title("A scatter plot")
plt.grid(visible = True)
plt.legend()
plt.show()

# %%
date, temperature = np.loadtxt('temperatures_ghana.txt', unpack=True)

fig = plt.figure(figsize= (10,10))
fig.tight_layout()

plt.scatter(date,temperature)
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.title("A scatter plot")
plt.grid(visible = True)
plt.show()

# %%
date, temperature = np.loadtxt('temperatures_ghana.txt', unpack=True)

fig = plt.figure(figsize= (10,10))
fig.tight_layout()

plt.scatter(date,temperature, alpha = 0.5)  #alpha is for transparency
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.title("A scatter plot")
plt.grid(visible = True)
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_excel("franck_hertz.xlsx")

# %%
df
# Out:
#      Acceleration Potential (VG2k)  Plate Current (IpA) Multiplier 10-9
# 0                              1.0                                 0.06
# 1                              1.5                                 0.06
# 2                              2.0                                 0.06
# 3                              2.5                                 0.06
# 4                              3.0                                 0.06
# ..                             ...                                  ...
# 196                           90.0                                 1.52
# 197                           90.5                                 1.46
# 198                           91.0                                 1.43
# 199                           91.5                                 1.37
# 200                           92.0                                 1.32
#
# [201 rows x 2 columns]

# %%
VG = np.array(df["Acceleration Potential (VG2k)"])
I = np.array(df["Plate Current (IpA) Multiplier 10-9"])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(VG, I, color = "blue", label = "Exp. Data")
ax.title.set_text(r"Frank-Hertz Expt. Data")
plt.legend(loc = "upper left")
plt.xlabel(r"Accelereating Voltage $V_{G2K}$ (volt)")
plt.ylabel(r"Plate Current ($10^{-9}$Amp)")
plt.xlim(0,94)
plt.ylim(0, 1.75)
plt.show()

# %% [markdown]
# ## Plot Histogram

# %%
res = np.random.randn(1000)*0.2 + 0.4

# %%
plt.figure(figsize = (10,4))
plt.hist(res, bins = 80)
plt.show()

# %%
plt.figure(figsize = (10,4))
plt.hist(res)
plt.show()

# %%
# only draw the boundary

# %%
plt.figure(figsize = (10,4))
plt.hist(res, bins = 80, density = True, histtype = "step")
plt.xlabel("$\hat{E}-E$", fontsize = 20)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # SubFigures

# %%
fig, axes = plt.subplots(2,2, figsize =(8,8))

ax = axes[0][0]
ax.plot(x,y, "o--", color = "r", lw = 0.4, ms = 3)
ax.set_xlabel("x-axis for 1st plot")

ax = axes[1][1]
ax.hist(res, bins = 30, density = True, histtype = "step", label = "C1")

ax = axes[0][1]
ax.plot(VG, I, marker = "o", markeredgecolor = "blue", markerfacecolor = "red", label = "Exp.Data")
ax.set_xlabel("x-axis")
ax.legend()

fig.tight_layout()
fig.suptitle("Title of All Plots", y = 1.03, fontsize = 25)
plt.show()

# %% [markdown]
# # Basic 2D Plots

# %%
x = np.linspace(1,100,10_000)
y = np.linspace(1,100,10_000)
x_v, y_v = np.meshgrid(x,y)

# %%
x_v
# Out:
# array([[  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ],
#        [  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ],
#        [  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ],
#        ...,
#        [  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ],
#        [  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ],
#        [  1.        ,   1.00990099,   1.01980198, ...,  99.98019802,
#          99.99009901, 100.        ]])

# %%
y_v
# Out:
# array([[  1.        ,   1.        ,   1.        , ...,   1.        ,
#           1.        ,   1.        ],
#        [  1.00990099,   1.00990099,   1.00990099, ...,   1.00990099,
#           1.00990099,   1.00990099],
#        [  1.01980198,   1.01980198,   1.01980198, ...,   1.01980198,
#           1.01980198,   1.01980198],
#        ...,
#        [ 99.98019802,  99.98019802,  99.98019802, ...,  99.98019802,
#          99.98019802,  99.98019802],
#        [ 99.99009901,  99.99009901,  99.99009901, ...,  99.99009901,
#          99.99009901,  99.99009901],
#        [100.        , 100.        , 100.        , ..., 100.        ,
#         100.        , 100.        ]])

# %%
z = x_v**2 + y_v**2

# %%
z
# Out:
# array([[2.00000000e+00, 2.01990001e+00, 2.03999608e+00, ...,
#         9.99704000e+03, 9.99901990e+03, 1.00010000e+04],
#        [2.01990001e+00, 2.03980002e+00, 2.05989609e+00, ...,
#         9.99705990e+03, 9.99903980e+03, 1.00010199e+04],
#        [2.03999608e+00, 2.05989609e+00, 2.07999216e+00, ...,
#         9.99707999e+03, 9.99905990e+03, 1.00010400e+04],
#        ...,
#        [9.99704000e+03, 9.99705990e+03, 9.99707999e+03, ...,
#         1.99920800e+04, 1.99940599e+04, 1.99960400e+04],
#        [9.99901990e+03, 9.99903980e+03, 9.99905990e+03, ...,
#         1.99940599e+04, 1.99960398e+04, 1.99980199e+04],
#        [1.00010000e+04, 1.00010199e+04, 1.00010400e+04, ...,
#         1.99960400e+04, 1.99980199e+04, 2.00000000e+04]])

# %%
plt.contourf(x_v, y_v, z)
plt.show()

# %%
plt.contourf(x_v, y_v, z, levels = 50, cmap = "plasma")
plt.colorbar(label = " Temp [$^\circ c$]")
plt.xlabel("Horizontal Position [m]")
plt.ylabel("Vertical Position [m]")
# Out:
# Text(0, 0.5, 'Vertical Position [m]')

# %%
cs =  plt.contour(x_v, y_v, z, levels = 20)
plt.clabel(cs, fontsize = 8)
# Out:
# <a list of 19 text.Text objects>

# %% [markdown]
# ## Error Bars

# %%
fig = plt.figure()
fig.tight_layout()


x = 5*np.random.random(10)
y = 2.5*x + 0.8

err = 0.5 
noise = np.random.normal(scale = err, size = len(x))
y_data = y + noise 

plt.plot(x, y, color = "k")
plt.errorbar(x, y_data, yerr= err, fmt = ".", capsize = 3, color = "r")

plt.xlabel("x[arbitrary units]")
plt.ylabel("y[arbitrart units]")

# We can also set some other formatting options, like axis limits
plt.xlim(0, 5)
plt.ylim(0, 12)

plt.show()

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x/20* np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr = yerr, label = "both limits (default)")
plt.errorbar(x, y + 2, yerr = yerr, uplims = True, label = "uplime = True")
plt.errorbar(x, y + 1, yerr = yerr, uplims = True, lolims = True, label = "uplims = True, lolims = True")

upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x,y, yerr = yerr, uplims = upperlimits, lolims = lowerlimits, label = "Subsets of uplims and lolims")

plt.legend(loc = "lower right", fontsize = 12)
plt.show()

# %% [markdown]
# # Basic 3D plots

# %%
# Define x and y arrays (you need to define a z array as well)
x = np.linspace(0, 15, 30)
y = np.linspace(0, 10, 30)
x, y = np.meshgrid(x, y)  # Create a grid of x and y values

# Define a z array based on some function (e.g., a plane)
z = 2 * x + 3 * y  # Replace this with your actual data

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='coolwarm')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Surface Plot')
plt.show()

# %% [markdown]
# # Application in Astronomy

# %%
from astropy.io import fits
from astropy.wcs import WCS

hdul = fits.open('s0002.fits')
data = hdul[0].data
h1 = hdul[0].header
obj_name = h1.get('OBJECT', 'Unknown')

flux = data[0]
w = WCS(h1, naxis=1, relax=False, fix=False)
wvl = w.wcs_pix2world(np.arange(len(flux)), 0)[0]

plt.plot(wvl, flux)

plt.axvline(x=5895.6, color='red', linestyle='--', label='Na Absorption')
plt.axvline(x=4364.436, color='black', linestyle='--', label=r'$O_{III}$ Emissive')
plt.legend()
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Normalized flux')
plt.show()

# %%
pip install astroquery
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from astroquery.gaia import Gaia
from astropy.table import Table

# %%
tables = Gaia.load_tables(only_names = True)
for table in tables: 
    if "gaiadr3" in table.get_qualified_name():
        print(table.get_qualified_name())
# Out:
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# INFO: Parsing tables... [astroquery.utils.tap.core]
# INFO: Done. [astroquery.utils.tap.core]
# gaiadr3.gaiadr3.gaia_source
# gaiadr3.gaiadr3.gaia_source_lite
# gaiadr3.gaiadr3.astrophysical_parameters
# gaiadr3.gaiadr3.astrophysical_parameters_supp
# gaiadr3.gaiadr3.oa_neuron_information
# gaiadr3.gaiadr3.oa_neuron_xp_spectra
# gaiadr3.gaiadr3.total_galactic_extinction_map
# gaiadr3.gaiadr3.total_galactic_extinction_map_opt
# gaiadr3.gaiadr3.commanded_scan_law
# gaiadr3.gaiadr3.allwise_best_neighbour
# gaiadr3.gaiadr3.allwise_neighbourhood
# gaiadr3.gaiadr3.apassdr9_best_neighbour
# gaiadr3.gaiadr3.apassdr9_join
# gaiadr3.gaiadr3.apassdr9_neighbourhood
# gaiadr3.gaiadr3.dr2_neighbourhood
# gaiadr3.gaiadr3.gsc23_best_neighbour
# gaiadr3.gaiadr3.gsc23_join
# gaiadr3.gaiadr3.gsc23_neighbourhood
# gaiadr3.gaiadr3.hipparcos2_best_neighbour
# gaiadr3.gaiadr3.hipparcos2_neighbourhood
# gaiadr3.gaiadr3.panstarrs1_best_neighbour
# ...

# %%
query = """SELECT source_id, ra, dec, parallax, phot_g_mean_mag, phot_bp_mean_mag, phot_rp_mean_mag FROM gaiadr3.gaia_source WHERE parallax > 50"""
job = Gaia.launch_job_async(query)
gtable = job.get_results()
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
print(gtable.info)
# Out:
# <Table length=2626>
#       name        dtype  unit                            description                             n_bad
# ---------------- ------- ---- ------------------------------------------------------------------ -----
#        source_id   int64      Unique source identifier (unique within a particular Data Release)     0
#               ra float64  deg                                                    Right ascension     0
#              dec float64  deg                                                        Declination     0
#         parallax float64  mas                                                           Parallax     0
#  phot_g_mean_mag float32  mag                                              G-band mean magnitude     6
# phot_bp_mean_mag float32  mag                                       Integrated BP mean magnitude    60
# phot_rp_mean_mag float32  mag                                       Integrated RP mean magnitude    54

# %%
bp_rp = gtable["phot_bp_mean_mag"] - gtable["phot_rp_mean_mag"]
fig, ax = plt.subplots(1,1, figsize = (8,8))
ax.hexbin(bp_rp, gtable["phot_g_mean_mag"], bins = "log", mincnt = 1)
ax.set_xlabel(r"$G_{BP} - G_{RP}$")
ax.set_ylabel(r"G")
ax.set_title("Hertzsprung Russell Diagram Before Filtering from Gaia3")
ax.invert_yaxis()
plt.show()

# %%
abs_gmag = 5*np.log10(gtable["parallax"]) - 10 + gtable["phot_g_mean_mag"]
fig,ax = plt.subplots(1,1, figsize = (8,8))
ax.hexbin(bp_rp, abs_gmag, bins = "log", mincnt = 1)
ax.set_xlabel(r"$G_{BP} - G_{RP}$")
ax.set_ylabel(r"G")
ax.set_title("Hertzsprung Russell Diagram After Filtering from Gaia3")
ax.invert_yaxis()
plt.show()

# %%
# We can also use fits file to make coloured mapped plots.

# %%
h = fits.open("example_data.fits")
data = h[0].data
plt.imshow(np.log(data))
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13740\3302033820.py:3: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(data))

# %%
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.utils.data import get_pkg_data_filename
image_file = get_pkg_data_filename("tutorials/FITS-images/HorseHead.fits")

# %%
image_data = fits.getdata(image_file, ext = 0)
plt.figure()
plt.imshow(image_data, cmap = "gray")
plt.colorbar()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13740\3332218090.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# ## Exercise

# %% [markdown]
# Below are some fake data for you to plot.Try making a plot that has three axes on top of each othe
#
# (Top plot): A scatterplot of the data. Add in errorbars for the y-values.
#
# (Middle plot): Draw a straight line through the data, tweaking the values for the line until it looks like it goes through all the points equally well. Make a legend specifying the line from the data.
#
# (Bottom plot): A histogram of the x and y data on a single plot.

# %%
x = np.array([7.1,9.4,9.1,3.6,2.6,4.1,3.8,6.4,8.8,9.8,
              6.0,9.8,8.5,0.6,5.9,7.5,0.9,5.5,4.6,9.])
y = np.array([21.0,25.3,24.8,10.0,9.2,9.0,11.3,17.0,24.0,27.1,
              18.0,25.8,23.2,4.0,17.2,19.1,2.9,13.6,11.4,25.])
yerr = 1

# %%
# Create fig and axes objects for subplots with 1 column and 3 rows
fig,axes = plt.subplots(3,1, figsize = (6,18))
# Subplot 1
ax = axes[0]
ax.scatter(x,y)
ax.errorbar(x,y, yerr=yerr, capsize = 5, fmt = "none")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Scatter Plot with Error Bars")

# Subplot 2
ax = axes[1]
coefficients = np.polyfit(x, y, 1)
line = np.poly1d(coefficients)
line_x = np.linspace(min(x), max(x), 100)
line_y = line(line_x)
ax.scatter(x, y)
ax.plot(line_x,line_y)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Scatter with line of Best of Fit")

# Subplot 3
ax = axes[2]
ax.hist(x, bins = 8, alpha = 0.5)
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")
ax.set_title("Hist of X")


fig.tight_layout()
plt.show()

# %% [markdown]
# # Extended Exercises

# %% [markdown]
# ## Exercises 1

# %% [markdown]
# Use Numpy to generate 10000 random values following a Gaussian/Normal distribution, and make a histogram. Try changing the number of bins to properly see the Gaussian. Try overplotting a Gaussian function on top of it using a colored line, and adjust the normalization so that the histogram and the line are aligned

# %%
mean = 50 
stdev = 10
N = 10000

x = np.random.normal(loc = mean, scale = stdev, size = N)
# random, normally distributed data points

#hist the data
fig, ax = plt.subplots(1,1, figsize = (8,5))
n, bins, patches = ax.hist(x, bins = 50, density = 1, facecolor = "g", alpha = 0.75)

#Play around with the hist() variables, see how they affect the plot!

ax.set(xlabel = "Random Value", ylabel = "Probability", title = "Gaussian Random Variable",
      xlim = [0,100], ylim = [0, 0.045])

ax.grid(True) # Shows gridlines

# Draw a vertical line at the mean and +/- 1 standard deviation
ax.axvline(mean, ls = "--", color = "g", lw = 2)
ax.axvline(mean + stdev, ls = "--", color = "r", lw = 2)
ax.axvline(mean - stdev, ls = "--", color = "r", lw = 2)

fig.suptitle("A Histogram", y = 1.001)

# Annotate the figure by placing text describing the mean and stdev
fig.text(0.6, .7, r'$\mu={:d}$, $\sigma={:d}$'.format(mean, stdev),
                    horizontalalignment='left', # abbreviate with ha=
                    verticalalignment='center')   # "  " va=
# Out:
# Text(0.6, 0.7, '$\\mu=50$, $\\sigma=10$')

# %% [markdown]
# ## Exercises 2

# %% [markdown]
# The central limit theorem states that the arithmetic mean of a large number of independent random samples (from any distribution) will approach a normal distribution. You can easily test this with Numpy and Matplotlib:
#
# Create an empty array total with 10000 values (set to 0)
# Generate 10000 random values uniformly between 0 and 1
# Add these values to the total array
# Repeat steps 2 and 3 10 times
# Divide total by 10 to get the mean of the values you added
# Make a histogram of the values in total
# You can also see how the histogram of total values changes at each step, if you want to see the evolution!
